# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# bar plot
iris.petal_length.value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
sns.countplot(x ="petal_length", data = iris)
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='count'>

# %%
sns.countplot(x ="petal_length", data = iris, hue = "species")
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='count'>

# %%
# Scatter plot
sns.scatterplot(x = "petal_length", y = "petal_width", hue="species", data = iris)
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='petal_width'>

# %%
# scatter plot using plt command
plt.scatter(x = 'petal_length', y = 'species', c = 'petal_width', data = iris)

colors = {1:'red', 2:'blue', 3:'green'}

# %%
sns.pairplot(iris)

# %%
iris.hist(bins = 30, figsize = (12, 8), color = 'b')
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %%
sns.boxplot(x = "species", y = "sepal_length", data = iris)
# Out:
# <AxesSubplot: xlabel='species', ylabel='sepal_length'>

# %%
sns.boxenplot(x = "species", y = "sepal_length", data = iris)
# Out:
# <AxesSubplot: xlabel='species', ylabel='sepal_length'>

# %%
# facet grid


g = sns.FacetGrid(iris, col = "species", margin_titles=True, palette={1:"seagreen", 0:"gray"})
g = g.map(plt.scatter, "petal_length", "petal_width", edgecolor="w").add_legend()

# %%
sns.stripplot(x = "species", y = "petal_length", hue="species", data = iris)
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
corr = iris.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr)
plt.title("Heatmap of Titanic Dataset", fontsize=20)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7420\411402699.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = iris.corr()
# Text(0.5, 1.0, 'Heatmap of Titanic Dataset')

# %%
sns.violinplot(x = "species", y = "petal_width", data = iris)
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_width'>
